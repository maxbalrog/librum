# %%
import numpy as np
import matplotlib.pyplot as plt

import scipy
from scipy import signal

import cv2

import skimage
from skimage import feature
from skimage.transform import rotate
from skimage import transform

import tensorflow as tf
import torch

import glob
import os

import sys
sys.path.append('book_recognition/bookshelves/*.jpg')

import book_recognition
from book_recognition.book_segmentation import *
from book_recognition.title_detector import *

# %%
dataset = glob.glob('book_dataset/bookshelves/*.jpg')
print('Dataset len: {}'.format(len(dataset)))
print('Dataset samples:')

idx = [0,1]
plt.figure(dpi=150)
for i,j in enumerate(idx):
    img = cv2.imread(dataset[j])
    
    plt.subplot(1,len(idx),i+1)
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.axis('off')
plt.show()
# Out:
# Dataset len: 15
# Dataset samples:

# %%
idx = 0
path = dataset[idx]
test_img = cv2.imread(path)
plot_img(test_img)

img_resc, img_rotated, lines_filtered, lines_rotated = book_segment.rotate_img(test_img)
books = extract_books_warped(img_rotated, lines_rotated)

plt.figure(dpi=200)
for i,book in enumerate(books):
    plt.subplot(1,len(books),i+1)
    plt.imshow(cv2.cvtColor(book, cv2.COLOR_BGR2RGB))
    plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-50-11011b262170> in <module>
#       2 path = dataset[idx]
#       3 test_img = cv2.imread(path)
# ----> 4 plot_img(test_img)
#       5
#       6 img_resc, img_rotated, lines_filtered, lines_rotated = book_segment.rotate_img(test_img)
#
# ~/Scripts/CV/project/librum/book_recognition/book_segmentation.py in plot_img(img)
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3
#       4 import scipy
#       5 from scipy import signal
#
# NameError: name 'plt' is not defined
